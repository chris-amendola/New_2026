# %%
import os
myCmd = 'dir'
os.system(myCmd)
# Out:
# 0

# %%
import subprocess
MyOut = subprocess.Popen(['dir'], stdout=subprocess.PIPE)
stdout = MyOut.communicate()
print(stdout)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-5abad11adfd5> in <module>()
#       1 import subprocess
# ----> 2 MyOut = subprocess.Popen(['dir'], stdout=subprocess.PIPE)
#       3 stdout = MyOut.communicate()
#       4 print(stdout)
#
# ~\AppData\Local\Continuum\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     707                                 c2pread, c2pwrite,
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#     711             # Cleanup if the child failed starting.
#
# ...
