# %%
srce='Y:\\SAS_Dev_Workspace\\easumen\\trunk\\SASApps\\Ihcis_wh\\Lehigh_OPA'
dest='Y:\\SAS_Dev_Workspace\\camendol\\trunk\\SASApps\\Ihcis_wh\\Lehigh_OPA'
files=''
file_list=files.split(" ")

# %%
srce='Y:\\SAS_Dev_Workspace\\easumen\\trunk\\SASApps\\Ihcis_wh\\Lehigh_OPA'
dest='Y:\\SAS_Dev_Workspace\\camendol\\trunk\\SASApps\\Ihcis_wh\\Lehigh_OPA'
files='Lehigh_OPA_copy_raw_files.xls\
 Lehigh_OPA_maps.sas attrib_clm_l_client_var.sas\
 attrib_clm_m_amt_var.sas\
 attrib_clm_m_client_var.sas\
 attrib_clm_p_amt_var.sas\
 attrib_clm_p_client_var.sas\
 attrib_input_elg.sas\
 attrib_input_med.sas\
 attrib_input_phm.sas\
 attrib_prv_map.sas\
 attrib_span_elg_client.sas\
 attrib_span_sub_client_var.sas\
 clm_l.sas\
 clm_m.sas\
 clm_p.sas\
 common_clm_m_DCS_rpt_v1.sas\
 common_clm_p_DCS_rpt_v1.sas\
 common_span_elg_DCS_rpt_v1.sas\
 common_span_elg_dw_v21_LEHIGH_OPA.sas\
 input_stmt_elg.sas\
 input_stmt_lab.sas\
 input_stmt_med.sas\
 input_stmt_phm.sas\
 input_stmt_sub.sas\
 invoke_DW_Lehigh_OPA.sas\
 modify_custom_peg_search_windows.sas\
 modify_o1_data_prep.sas\
 prv_map.sas\
 prv_modify.sas\
 span_elg.sas\
 span_sub.sas\
 common_o1_data_prep_v1.sas\
 common_o1_data_qc_v1.sas'
file_list=files.split(" ")

# %%
for file in file_list:
    print('copy '+srce+'\\'+file+' '+dest)
# Out:
# copy Y:\SAS_Dev_Workspace\easumen\trunk\SASApps\Ihcis_wh\Lehigh_OPA\Lehigh_OPA_copy_raw_files.xls Y:\SAS_Dev_Workspace\camendol\trunk\SASApps\Ihcis_wh\Lehigh_OPA
# copy Y:\SAS_Dev_Workspace\easumen\trunk\SASApps\Ihcis_wh\Lehigh_OPA\Lehigh_OPA_maps.sas Y:\SAS_Dev_Workspace\camendol\trunk\SASApps\Ihcis_wh\Lehigh_OPA
# copy Y:\SAS_Dev_Workspace\easumen\trunk\SASApps\Ihcis_wh\Lehigh_OPA\attrib_clm_l_client_var.sas Y:\SAS_Dev_Workspace\camendol\trunk\SASApps\Ihcis_wh\Lehigh_OPA
# copy Y:\SAS_Dev_Workspace\easumen\trunk\SASApps\Ihcis_wh\Lehigh_OPA\attrib_clm_m_amt_var.sas Y:\SAS_Dev_Workspace\camendol\trunk\SASApps\Ihcis_wh\Lehigh_OPA
# copy Y:\SAS_Dev_Workspace\easumen\trunk\SASApps\Ihcis_wh\Lehigh_OPA\attrib_clm_m_client_var.sas Y:\SAS_Dev_Workspace\camendol\trunk\SASApps\Ihcis_wh\Lehigh_OPA
# copy Y:\SAS_Dev_Workspace\easumen\trunk\SASApps\Ihcis_wh\Lehigh_OPA\attrib_clm_p_amt_var.sas Y:\SAS_Dev_Workspace\camendol\trunk\SASApps\Ihcis_wh\Lehigh_OPA
# ...

# %%
srce='Y:\\SAS_Dev_Workspace\\easumen\\trunk\\SASApps\\Impact_Analysis_PULL\\Clients\\Lehigh_OPA'
dest='Y:\\SAS_Dev_Workspace\\camendol\\trunk\\SASApps\\Impact_Analysis_PULL\\Clients\\Lehigh_OPA'
files='DropRecord_Provider_Lehigh_OPA.sas\
 Modify_labdata.sas\
 Modify_member.sas\
 Modify_provider.sas\
 Modify_servicemed.sas\
 Modify_servicerx.sas\
 Modify_subscriber.sas\
 attrib_member_Lehigh_OPA.sas\
 attrib_provider_Lehigh_OPA.sas\
 attrib_servicemed_Lehigh_OPA.sas\
 attrib_servicerx_Lehigh_OPA.sas\
 attrib_subscriber_Lehigh_OPA.sas\
 invoke_ia_pull_Lehigh_OPA.sas\
 modify_maps_drg_map.sas\
 modify_maps_non_standard.sas\
 modify_maps_pos.sas\
 modify_maps_spec.sas\
 modify_maps_tos.sas'
file_list=files.split(" ")
for file in file_list:
    print('copy '+srce+'\\'+file+' '+dest)
# Out:
# copy Y:\SAS_Dev_Workspace\easumen\trunk\SASApps\Impact_Analysis_PULL\Clients\Lehigh_OPA\DropRecord_Provider_Lehigh_OPA.sas Y:\SAS_Dev_Workspace\camendol\trunk\SASApps\Impact_Analysis_PULL\Clients\Lehigh_OPA
# copy Y:\SAS_Dev_Workspace\easumen\trunk\SASApps\Impact_Analysis_PULL\Clients\Lehigh_OPA\Modify_labdata.sas Y:\SAS_Dev_Workspace\camendol\trunk\SASApps\Impact_Analysis_PULL\Clients\Lehigh_OPA
# copy Y:\SAS_Dev_Workspace\easumen\trunk\SASApps\Impact_Analysis_PULL\Clients\Lehigh_OPA\Modify_member.sas Y:\SAS_Dev_Workspace\camendol\trunk\SASApps\Impact_Analysis_PULL\Clients\Lehigh_OPA
# copy Y:\SAS_Dev_Workspace\easumen\trunk\SASApps\Impact_Analysis_PULL\Clients\Lehigh_OPA\Modify_provider.sas Y:\SAS_Dev_Workspace\camendol\trunk\SASApps\Impact_Analysis_PULL\Clients\Lehigh_OPA
# copy Y:\SAS_Dev_Workspace\easumen\trunk\SASApps\Impact_Analysis_PULL\Clients\Lehigh_OPA\Modify_servicemed.sas Y:\SAS_Dev_Workspace\camendol\trunk\SASApps\Impact_Analysis_PULL\Clients\Lehigh_OPA
# ...

# %%
#Y:\\SAS_Dev_Workspace\easumen\trunk\SASApps\Impact_Analysis_Upload\Clients\Lehigh_OPA
srce='Y:\\SAS_Dev_Workspace\\easumen\\trunk\\SASApps\\Impact_Analysis_Upload\\Clients\\Lehigh_OPA'
dest='Y:\\SAS_Dev_Workspace\\camendol\\trunk\\SASApps\\Impact_Analysis_Upload\\Clients\\Lehigh_OPA'
files='invoke_ia_upload_Lehigh_OPA.sas'
file_list=files.split(" ")
for file in file_list:
    print('copy '+srce+'\\'+file+' '+dest)
# Out:
# copy Y:\SAS_Dev_Workspace\easumen\trunk\SASApps\Impact_Analysis_Upload\Clients\Lehigh_OPA\invoke_ia_upload_Lehigh_OPA.sas Y:\SAS_Dev_Workspace\camendol\trunk\SASApps\Impact_Analysis_Upload\Clients\Lehigh_OPA

# %%
#Y:\\SAS_Dev_Workspace\easumen\trunk\SASApps\Impact_Analysis_PRE_PE\Clients\Lehigh_OPA
srce='Y:\\SAS_Dev_Workspace\\easumen\\trunk\\SASApps\\Impact_Analysis_PRE_PE\\Clients\\Lehigh_OPA'
dest='Y:\\SAS_Dev_Workspace\\camendol\\trunk\\SASApps\\Impact_Analysis_PRE_PE\\Clients\\Lehigh_OPA'
files='invoke_IA_PRE_PE_DRG_Grouper_Lehigh_OPA.sas'
file_list=files.split(" ")
for file in file_list:
    print('copy '+srce+'\\'+file+' '+dest)
# Out:
# copy Y:\SAS_Dev_Workspace\easumen\trunk\SASApps\Impact_Analysis_PRE_PE\Clients\Lehigh_OPA\invoke_IA_PRE_PE_DRG_Grouper_Lehigh_OPA.sas Y:\SAS_Dev_Workspace\camendol\trunk\SASApps\Impact_Analysis_PRE_PE\Clients\Lehigh_OPA

# %%
#Y:\\SAS_Dev_Workspace\easumen\trunk\IDIA\ALL_Modules\Clients\Lehigh_OPA
srce='Y:\\SAS_Dev_Workspace\\easumen\\trunk\\IDIA\ALL_Modules\\Clients\\Lehigh_OPA'
dest='Y:\\SAS_Dev_Workspace\\camendol\\trunk\\IDIA\ALL_Modules\\Clients\\Lehigh_OPA'
files='LVP_Data_Paths_Setup.xls LVP_AUX_FILES.csv'
file_list=files.split(" ")
for file in file_list:
    print('copy '+srce+'\\'+file+' '+dest)
# Out:
# copy Y:\SAS_Dev_Workspace\easumen\trunk\IDIA\ALL_Modules\Clients\Lehigh_OPA\LVP_Data_Paths_Setup.xls Y:\SAS_Dev_Workspace\camendol\trunk\IDIA\ALL_Modules\Clients\Lehigh_OPA
# copy Y:\SAS_Dev_Workspace\easumen\trunk\IDIA\ALL_Modules\Clients\Lehigh_OPA\LVP_AUX_FILES.csv Y:\SAS_Dev_Workspace\camendol\trunk\IDIA\ALL_Modules\Clients\Lehigh_OPA
